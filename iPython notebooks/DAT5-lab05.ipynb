# %% [markdown]
# # GA Data Science 5 (DAT5) - Lab5
#
# ### Regressions
#
# Francesco Mosconi
# Chief Data Officer, [Spire Inc.](spire.io)

# %%
#usual imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# statsmodel APIs
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Load a subset of the housing data

# %%
data.all
# Out:
# <bound method DataFrame.all of     sqft  bedrooms  age   price
# 0   2104         3   70  399900
# 1   1600         3   28  329900
# 2   2400         3   44  369000
# 3   1416         2   49  232000
# 4   3000         4   75  539900
# 5   1985         4   61  299900
# 6   1534         3   12  314900
# 7   1427         3   57  198999
# 8   1380         3   14  212000
# 9   1494         3   15  242500
# 10  1940         4    7  239999
# 11  2000         3   27  347000
# 12  1890         3   45  329999
# 13  4478         5   49  699900
# 14  1268         3   58  259900
# 15  2300         4   77  449900
# 16  1320         2   62  299900
# 17  1236         3   78  199900
# 18  2609         4    5  499998
# 19  3031         4   21  599000
# 20  1767         3   44  252900
# 21  1888         2   79  255000
# 22  1604         3   13  242900
# 23  1962         4   53  259900
# 24  3890         3   36  573900
# 25  1100         3   60  249900
# 26  1458         3   29  464500
# 27  2526         3   13  469000
# 28  2200         3   28  475000
# 29  2637         3   25  299900
# 30  1839         2   40  349900
# 31  1000         1    5  169900
# 32  2040         4   75  314900
# 33  3137         3   67  579900
# 34  1811         4   24  285900
# 35  1437         3   50  249900
# 36  1239         3   22  229900
# 37  2132         4   28  345000
# 38  4215         4   66  549000
# 39  2162         4   43  287000
# 40  1664         2   40  368500
# 41  2238         3   37  329900
# 42  2567         4   57  314000
# 43  1200         3   76  299000
# 44   852         2   70  179900
# 45  1852         4   64  299900
# 46  1203         3   11  239500
#
# [47 rows x 4 columns]>

# %% [markdown]
# data = pd.read_csv('data/houses.csv')

# %%
data.head(48)
# Out:
#     sqft  bedrooms  age   price
# 0   2104         3   70  399900
# 1   1600         3   28  329900
# 2   2400         3   44  369000
# 3   1416         2   49  232000
# 4   3000         4   75  539900
# 5   1985         4   61  299900
# 6   1534         3   12  314900
# 7   1427         3   57  198999
# 8   1380         3   14  212000
# 9   1494         3   15  242500
# 10  1940         4    7  239999
# 11  2000         3   27  347000
# 12  1890         3   45  329999
# 13  4478         5   49  699900
# 14  1268         3   58  259900
# 15  2300         4   77  449900
# 16  1320         2   62  299900
# 17  1236         3   78  199900
# 18  2609         4    5  499998
# 19  3031         4   21  599000
# 20  1767         3   44  252900
# 21  1888         2   79  255000
# 22  1604         3   13  242900
# 23  1962         4   53  259900
# 24  3890         3   36  573900
# 25  1100         3   60  249900
# 26  1458         3   29  464500
# 27  2526         3   13  469000
# 28  2200         3   28  475000
# 29  2637         3   25  299900
# 30  1839         2   40  349900
# 31  1000         1    5  169900
# 32  2040         4   75  314900
# 33  3137         3   67  579900
# 34  1811         4   24  285900
# 35  1437         3   50  249900
# 36  1239         3   22  229900
# 37  2132         4   28  345000
# 38  4215         4   66  549000
# 39  2162         4   43  287000
# 40  1664         2   40  368500
# 41  2238         3   37  329900
# 42  2567         4   57  314000
# 43  1200         3   76  299000
# 44   852         2   70  179900
# 45  1852         4   64  299900
# 46  1203         3   11  239500
#
# [47 rows x 4 columns]

# %%
data.head()
# Out:
#    sqft  bedrooms  age   price
# 0  2104         3   70  399900
# 1  1600         3   28  329900
# 2  2400         3   44  369000
# 3  1416         2   49  232000
# 4  3000         4   75  539900
#
# [5 rows x 4 columns]

# %%
data_n = pd.read_csv('data/houses_norm.csv')

# %% [markdown]
# The dataset contains 4 columns. Our objective is to build a model that is able to predict the price of a house, using the information contained in the other columns (sqft, bedrooms and age)

# %%
from pandas.tools.plotting import scatter_matrix
scat = scatter_matrix(data, figsize = (15,15))

# %% [markdown]
# Run 1. x = sqft, data is raw (so graph units are nice right)

# %% [markdown]
# Let''s start with a simple model that uses the house surface to estimate the price

# %%
# the value turns this into an numpy array
x = data['sqft'].values
y = data['price'].values

# %%
# ols is ordinary leased square
X = sm.add_constant(x, prepend=True)

results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

plt.plot(x, y, 'bo')
plt.title("Price VS Sqft")
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     122.3
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.03e-14
# Time:                        20:37:24   Log-Likelihood:                -586.94
# No. Observations:                  47   AIC:                             1178.
# Df Residuals:                      45   BIC:                             1182.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       7.127e+04   2.61e+04      2.725      0.009      1.86e+04  1.24e+05
# x1           134.5253     12.165     11.058      0.000       110.024   159.027
# ==============================================================================
# Omnibus:                        3.751   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                2.726
# Skew:                           0.557   Prob(JB):                        0.256
# Kurtosis:                       3.390   Cond. No.                     5.88e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 5.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Run 2:  x = sqft, data is normalized (so summary stats are nice)

# %%
data_n.head()
# Out:
#     sqft  bedrooms  age  price
# 0  2.104         3  7.0  3.999
# 1  1.600         3  2.8  3.299
# 2  2.400         3  4.4  3.690
# 3  1.416         2  4.9  2.320
# 4  3.000         4  7.5  5.399
#
# [5 rows x 4 columns]

# %%
# the value turns this into an numpy array
x = data_n['sqft'].values
y = data_n['price'].values

# %%
# ols is ordinary leased square
X = sm.add_constant(x, prepend=True)

results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

plt.plot(x, y, 'bo')
plt.title("Price VS Sqft")
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     122.3
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.03e-14
# Time:                        20:45:09   Log-Likelihood:                -45.831
# No. Observations:                  47   AIC:                             95.66
# Df Residuals:                      45   BIC:                             99.36
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.7127      0.261      2.725      0.009         0.186     1.239
# x1             1.3453      0.122     11.058      0.000         1.100     1.590
# ==============================================================================
# Omnibus:                        3.751   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                2.726
# Skew:                           0.557   Prob(JB):                        0.256
# Kurtosis:                       3.390   Cond. No.                         7.01
# ==============================================================================
# """

# %% [markdown]
# Confidence Intervals

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std

prstd, iv_1, iv_u = wls_prediction_std(results)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, y, 'o', label="data")
ax.plot(x, results.fittedvalues, 'r-', label="OLS")
ax.plot(x, iv_u, 'r-')
ax.plot(x, iv_1, 'r-')
ax.legend(loc='best'); # find best place to put the legend

# %% [markdown]
# ## Function of Bedrooms?

# %% [markdown]
# Run 3:  x = bdrms, data is raw (so graph units are nice)

# %%
x = data['bedrooms'].values
y = data['price'].values

X = sm.add_constant(x, prepend=True)

results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

plt.plot(x, y, 'bo')
plt.title(r2)
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     10.94
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):            0.00185
# Time:                        20:50:24   Log-Likelihood:                -612.68
# No. Observations:                  47   AIC:                             1229.
# Df Residuals:                      45   BIC:                             1233.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         1.1e+05   7.16e+04      1.537      0.131     -3.41e+04  2.54e+05
# x1          7.267e+04    2.2e+04      3.308      0.002      2.84e+04  1.17e+05
# ==============================================================================
# Omnibus:                        4.709   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.412
# Skew:                           0.691   Prob(JB):                        0.110
# Kurtosis:                       2.413   Cond. No.                         15.4
# ==============================================================================
# """

# %% [markdown]
# ## Function of Age?

# %%
x = data['age'].values
y = data['price'].values 

X = sm.add_constant(x, prepend=True)

results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

plt.plot(x, y, 'bo')
plt.title(r2)
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
x = data_n['age'].values
y = data_n['price'].values 

X = sm.add_constant(x, prepend=True)

results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

plt.plot(x, y, 'bo')
plt.title(r2)
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                    0.1210
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):              0.730
# Time:                        20:52:13   Log-Likelihood:                -76.624
# No. Observations:                  47   AIC:                             157.2
# Df Residuals:                      45   BIC:                             160.9
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          3.2831      0.394      8.341      0.000         2.490     4.076
# x1             0.0283      0.081      0.348      0.730        -0.136     0.192
# ==============================================================================
# Omnibus:                        8.665   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.374
# Skew:                           1.025   Prob(JB):                       0.0152
# Kurtosis:                       3.270   Cond. No.                         10.7
# ==============================================================================
# """

# %% [markdown]
# ## Function of multiple variables

# %%
x = data_n[['sqft', 'bedrooms', 'age']].values
y - data_n['price'].values

X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                     39.38
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.12e-12
# Time:                        20:53:52   Log-Likelihood:                -45.641
# No. Observations:                  47   AIC:                             99.28
# Df Residuals:                      43   BIC:                             106.7
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.9245      0.449      2.060      0.045         0.019     1.830
# x1             1.3933      0.150      9.305      0.000         1.091     1.695
# x2            -0.0862      0.156     -0.551      0.584        -0.402     0.229
# x3            -0.0081      0.043     -0.188      0.852        -0.095     0.079
# ==============================================================================
# Omnibus:                        3.841   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                2.771
# Skew:                           0.552   Prob(JB):                        0.250
# Kurtosis:                       3.444   Cond. No.                         28.9
# ==============================================================================
# """

# %% [markdown]
# ## 3D Plot

# %%
# 3d plot
from mpl_toolkits.mplot3d import Axes3D

x = data[['sqft', 'bedrooms','age']].values
y = data['price'].values

fignum = 1
fig = plt.figure(fignum, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=38, azim=124)

plt.cla()
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()

# est.fit(X)
# ax.scatter(X[:, 0], X[:, 1], X[:, 3], c=labels.astype(np.float))
ax.scatter(X[:, 1], X[:, 0], X[:, 3])

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_ylabel('Sqft')
ax.set_xlabel('Bedrooms')
ax.set_zlabel('Price')
plt.show()

# %% [markdown]
# ## Just sqft & bedrooms

# %%
x = data_n[['sqft', 'bedrooms']].values
y = data_n['price'].values
X = sm.add_constant(x, prepend=True)
results = sm.OLS(y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     60.38
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.43e-13
# Time:                        20:58:27   Log-Likelihood:                -45.660
# No. Observations:                  47   AIC:                             97.32
# Df Residuals:                      44   BIC:                             102.9
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.8960      0.418      2.145      0.037         0.054     1.738
# x1             1.3921      0.148      9.409      0.000         1.094     1.690
# x2            -0.0874      0.155     -0.566      0.575        -0.399     0.224
# ==============================================================================
# Omnibus:                        4.083   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                2.977
# Skew:                           0.567   Prob(JB):                        0.226
# Kurtosis:                       3.484   Cond. No.                         18.0
# ==============================================================================
# """

# %% [markdown]
# ## The formula API

# %%
results = smf.ols('price ~ sqft + bedrooms', data=data).fit()

# smf is the package we loaded at the beginning: statsmodel formula api
# import statsmodels.formula.api as smf
# ~ means price is a dfunction of sqft and bedrooms

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     60.38
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           2.43e-13
# Time:                        21:01:27   Log-Likelihood:                -586.77
# No. Observations:                  47   AIC:                             1180.
# Df Residuals:                      44   BIC:                             1185.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    8.96e+04   4.18e+04      2.145      0.037      5421.208  1.74e+05
# sqft         139.2107     14.795      9.409      0.000       109.393   169.028
# bedrooms   -8738.0191   1.55e+04     -0.566      0.575     -3.99e+04  2.24e+04
# ==============================================================================
# Omnibus:                        4.083   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                2.977
# Skew:                           0.567   Prob(JB):                        0.226
# Kurtosis:                       3.484   Cond. No.                     9.71e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 9.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Nonlinear Fitting

# %% [markdown]
# Let's generate points with an arbitrary nonlinear function

# %% [markdown]
# $y = \frac{1}{2} x + \frac{1}{2} \sin{x} - \frac{1}{50} (x-5)^2 + 5$

# %%
# start with some fake data
nsample = 50
sig = 0.5
# generate linear space
x = np.linspace(0, 20, nsample) #generates the x's from 0 - 20, 50 times
# invent function
X = np.c_[x, np.sin(x), (x - 5)**2, np.ones(nsample)]
#invent coefficients
beta = [0.5, 0.5, -0.02, 5.]
# generate
y_true = np.dot(X, beta)
# add noise
y = y_true + sig * np.random.normal(size=nsample)

# %% [markdown]
# quick look at the data

# %%
# nice! ipython shortcuts!
plot(x, y_true)
scatter(x, y, c='g')
show()

# %%
res = sm.OLS(y, X).fit() #y is a function  of X
res.summary()

# coef is showing the general prediction values
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     202.4
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):           1.67e-26
# Time:                        21:10:17   Log-Likelihood:                -37.613
# No. Observations:                  50   AIC:                             83.23
# Df Residuals:                      46   BIC:                             90.87
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.5479      0.028     19.472      0.000         0.491     0.605
# x2             0.4808      0.111      4.347      0.000         0.258     0.703
# x3            -0.0255      0.002    -10.325      0.000        -0.030    -0.021
# const          4.8508      0.182     26.588      0.000         4.484     5.218
# ==============================================================================
# Omnibus:                        1.090   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.580   Jarque-Bera (JB):                0.965
# Skew:                          -0.114   Prob(JB):                        0.617
# Kurtosis:                       2.359   Cond. No.                         221.
# ==============================================================================
# """

# %% [markdown]
# I can access the results attributes

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     21.48
# Date:                Tue, 25 Mar 2014   Prob (F-statistic):            0.00566
# Time:                        18:06:21   Log-Likelihood:                -1.9268
# No. Observations:                   7   AIC:                             7.854
# Df Residuals:                       5   BIC:                             7.745
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.5022      0.144      3.479      0.018         0.131     0.873
# x1            -1.0965      0.237     -4.635      0.006        -1.705    -0.488
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.343
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.286
# Skew:                          -0.488   Prob(JB):                        0.867
# Kurtosis:                       2.842   Cond. No.                         1.68
# ==============================================================================
# """

# %% [markdown]
# Let's look at the fit!

# %% [markdown]
# ## Overfitting

# %%
x = np.array([-0.99768, -0.69574, -0.40373, -0.10236, 0.22024, 0.47742, 0.82229])
y = np.array([2.0885, 1.1646, 0.3287, 0.46013, 0.44808, 0.10013, -0.32952])

fig, ax = plt.subplots(figsize =(8,6))
ax.plot(x, y, 'o', markersize=12)
plt.xlim((-1.3, 1.3))
# Out:
# (-1.3, 1.3)

# %%
X = sm.add_constant(x, prepend=True)

results = sm.OLS(y, X).fit()
intercept, slope = results.params

r2 = results.rsquared

plt.plot(x, y, 'bo')
plt.title(r2)
x1 = np.array([min(x), max(x)])
y1 = intercept + slope * x1
plt.plot(x1, y1, 'r-')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
X = np.c_[x, np.ones(len(x))]
#X = np.vander(x, 1+1) - this is prepending the 1's to the data

# %%
plt.figure(figsize = (6,6));
plt.plot(x, y, 'o');
xx = np.linspace(-1.25,1.25,100)
plt.plot(xx, res.predict(np.vander(xx,3)), 'r-');
plt.title('blue: true, red: OLS');

# %%
res = sm.OLS(y, X).fit() #y is a function  of X - this is the linear fit
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     21.48
# Date:                Mon, 24 Mar 2014   Prob (F-statistic):            0.00566
# Time:                        21:14:00   Log-Likelihood:                -1.9268
# No. Observations:                   7   AIC:                             7.854
# Df Residuals:                       5   BIC:                             7.745
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -1.0965      0.237     -4.635      0.006        -1.705    -0.488
# const          0.5022      0.144      3.479      0.018         0.131     0.873
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.343
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.286
# Skew:                          -0.488   Prob(JB):                        0.867
# Kurtosis:                       2.842   Cond. No.                         1.68
# ==============================================================================
# """

# %% [markdown]
# ### Linear fit

# %% [markdown]
# ### Quadratic

# %%
X = np.c_[x**2, x, np.ones(len(x))]
res = sm.OLS(y, X).fit()

plt.figure(figsize = (6,6));
plt.plot(x, y, 'o');
xx = np.linspace(-1.25,1.25,100)
plt.plot(xx, res.predict(np.vander(xx,3)), 'r-');
plt.title('blue: true, red: OLS');

# %% [markdown]
# ### Quintic

# %%
X = np.c_[x**5, x**4, x**3, x**2, x, np.ones(len(x))]
res = sm.OLS(y, X).fit()

plt.figure(figsize = (10,10));
plt.plot(x, y, 'o');
xx = np.linspace(-1.25,1.25,100)
plt.plot(xx, res.predict(np.vander(xx,6)), 'r-');
plt.title('blue: true, red: OLS');

# %% [markdown]
# ## Regularization

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
ridge = Ridge()
ridge.fit(np.vander(x, 6), y)

lasso = Lasso(alpha = 0.1)
lasso.fit(np.vander(x, 6), y)

plt.figure(figsize = (10,10));
plt.plot(x, y, 'o')
xx = np.linspace(-1.25,1.1,100)
plt.plot(xx, res.predict(np.vander(xx,6)), 'r-');
plt.plot(xx,  ridge.predict(np.vander(xx, 6)), 'g-', label='Ridge');
plt.plot(xx,  lasso.predict(np.vander(xx, 6)), 'c-', label='Lasso');
plt.legend(loc='best')

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     21.48
# Date:                Tue, 25 Mar 2014   Prob (F-statistic):            0.00566
# Time:                        18:03:02   Log-Likelihood:                -1.9268
# No. Observations:                   7   AIC:                             7.854
# Df Residuals:                       5   BIC:                             7.745
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.5022      0.144      3.479      0.018         0.131     0.873
# x1            -1.0965      0.237     -4.635      0.006        -1.705    -0.488
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.343
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.286
# Skew:                          -0.488   Prob(JB):                        0.867
# Kurtosis:                       2.842   Cond. No.                         1.68
# ==============================================================================
# """
