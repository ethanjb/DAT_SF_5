# %%
from pandas.io.data import DataReader
from datetime import datetime
yhoo = DataReader("YHOO",  "yahoo", datetime(2012,1,1), datetime(2014,4,1))
aapl = DataReader("AAPL",  "yahoo", datetime(2012,1,1), datetime(2014,4,1))
aapl.head(15)
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2012-01-03  409.40  412.50  409.00  411.23  10793600     395.26
# 2012-01-04  410.00  414.68  409.28  413.44   9286500     397.38
# 2012-01-05  414.95  418.55  412.67  418.03   9688200     401.79
# 2012-01-06  419.77  422.75  419.22  422.40  11367600     405.99
# 2012-01-09  425.50  427.75  421.35  421.73  14072300     405.35
# 2012-01-10  425.91  426.00  421.50  423.24   9221300     406.80
# 2012-01-11  422.68  422.85  419.31  422.55   7681600     406.14
# 2012-01-12  422.28  422.90  418.75  421.39   7592400     405.02
# 2012-01-13  419.70  420.45  418.66  419.81   8072200     403.50
# 2012-01-17  424.20  425.99  422.96  424.70   8674900     408.20
# 2012-01-18  426.96  429.47  426.30  429.11   9885400     412.44
# 2012-01-19  430.15  431.37  426.51  427.75   9347800     411.13
# 2012-01-20  427.49  427.50  419.75  420.30  14784800     403.97
# 2012-01-23  422.67  428.45  422.30  427.41  10930800     410.81
# ...

# %%
ticker.to_csv('data/YHOO.csv', sep='\t', encoding='utf-8')
ticker.to_csv('data/AAPL.csv', sep='\t', encoding='utf-8')
